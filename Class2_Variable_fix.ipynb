# %% [markdown]
# # 변수(Variable)

# %%
milk=100
print(milk)
# Out:
# 100

# %%
milk=200
print(milk)
# Out:
# 200

# %%
count =10

# %%
count = count + 1
print(count)
# Out:
# 11

# %%
A=1
a=2
print(A)
print(a)
# Out:
# 1
# 2

# %%
print(a,1)
# Out:
# 2 1

# %%
a, b = 3, 4
print(a)
print(b)
# Out:
# 3
# 4

# %%
가격=1000
print(가격)
# Out:
# 1000

# %%
x = y = z = "same"

print (x)
print (y)
print (z)
# Out:
# same
# same
# same

# %% [markdown]
# # 자료형 (Data Type)

# %%
type(x)
# Out:
# str

# %%
type(a)
# Out:
# int

# %%
type(3.5)
# Out:
# float

# %%
type('abc')
# Out:
# str

# %%
type(1)
# Out:
# int

# %%
type('1')
# Out:
# str

# %%
type(1.0)
# Out:
# float

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
3e9
# Out:
# 3000000000.0

# %%
1e-1
# Out:
# 0.1

# %%
3e-4
# Out:
# 0.0003

# %%
a = '''
안녕하세요
오늘은
2번째 
이론 수업이네요

'''

# %%
print(a)
# Out:
# 안녕하세요
# 오늘은
# 2번째
# 이론 수업이네요

# %%
b="""
네 
그렇군요

"""

# %%
print(b)
# Out:
# 네
# 그렇군요

# %% [markdown]
# # 주석 (Comment)

# %%
print('이것은 주석 예제입니다.') #print('이건 실행 안 됩니다.')
# Out:
# 이것은 주석 예제입니다.

# %%
'''
print(10)
print('a')

'''
print(100)
# Out:
# 100

# %%
"""
print(10)
print('a')
"""
print(100)
# Out:
# 100

# %% [markdown]
# # 출력문

# %%
print('재미있는 수업')
# Out:
# 재미있는 수업

# %%
age = 20

# %%
print('저는',age,'살 입니다.')
# Out:
# 저는 20 살 입니다.

# %%
print('4차'+'산업혁명')
# Out:
# 4차산업혁명

# %%
print('사랑해 '*10)
# Out:
# 사랑해 사랑해 사랑해 사랑해 사랑해 사랑해 사랑해 사랑해 사랑해 사랑해

# %% [markdown]
# # 입력문

# %%
input()
# Out:
# 3
# '3'

# %%
나이 = input('나이를 입력해주세요')
# Out:
# 나이를 입력해주세요20

# %%
print('당신의 나이는',나이, '살입니다')
# Out:
# 당신의 나이는 20 살입니다

# %%
type(나이)
# Out:
# str

# %%
나이 + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-9645d661fc7d> in <module>()
# ----> 1 나이 + 3
#
# TypeError: must be str, not int

# %% [markdown]
# # 형변환

# %%
age = input('how old are you? ')
# Out:
# how old are you? 20

# %%
print(age)
# Out:
# 20

# %%
type(age)
# Out:
# str

# %%
age = int(age)

# %%
type(age)
# Out:
# int

# %%
age + 10
# Out:
# 30

# %%
age_str = str(age)

# %%
age_str
# Out:
# '20'

# %%
type(age_str)
# Out:
# str

# %%
f = '2.12'

# %%
f2 = float(f)
